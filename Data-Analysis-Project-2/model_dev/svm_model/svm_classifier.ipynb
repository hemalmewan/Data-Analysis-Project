# %% [markdown]
# ## **Import Required Libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.metrics import classification_report,f1_score,precision_score,accuracy_score,recall_score
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ## **Load the Datasets**

# %%
train_data=pd.read_csv("C:\\UOC pdf\\4th Year\\Machine Learning-02\\Data-Analysis-Project-2\\data\\train_data.csv")
test_data=pd.read_csv("C:\\UOC pdf\\4th Year\\Machine Learning-02\\Data-Analysis-Project-2\\data\\test_data.csv")

# %%
train_data=train_data.drop(columns=["Unnamed: 0"],axis=1)
test_data=test_data.drop(columns=["Unnamed: 0"],axis=1)

# %% [markdown]
# ## **Split X_train,Y_train and X_test,Y_test**

# %%
X_train=train_data.drop(columns=["diagnosis"],axis=1)
Y_train=train_data["diagnosis"]
X_test=test_data.drop(columns=["diagnosis"],axis=1)
Y_test=test_data["diagnosis"]

# %%
print(f"Shape of the Training set:{X_train.shape,Y_train.shape}")
print(f"Shape of  the Testing set:{X_test.shape,Y_test.shape}")
# Out:
# Shape of the Training set:((700, 15), (700,))
# Shape of  the Testing set:((300, 15), (300,))

# %% [markdown]
# ## **Build the Pipeline**

# %%
num_cols=X_train.select_dtypes(include="number").columns  ##get the all numerical column names
cat_cols=X_train.select_dtypes(include=["object","category"]).columns ##get the all categorical column names

# %%
nominal_cols=["gender","pem_present","meditation_or_mindfulness"] ##nominal columns
ordinal_cols=["work_status","social_activity_level","exercise_frequency"] ##ordinal columns

# %% [markdown]
# #### **Define the Pipeline**

# %%
numerical_pipeline=Pipeline(steps=[
    ("Scale",StandardScaler())                ##Numberical varaibles pipeline
])
ordinal_pipeline=Pipeline(steps=[
    ("Ordinal Encoder",OrdinalEncoder())      ##Ordinal variable pipeline
])
nominal_pieline=Pipeline(steps=[
    ("Nominal Encoder",OneHotEncoder(sparse_output=False,handle_unknown="ignore"))  ##Nominal variable pipeline
])

# %% [markdown]
# #### **Combine Pipelines**

# %%
Transfomers=ColumnTransformer(transformers=[
    ("Numerical Pipeline",numerical_pipeline,num_cols), ##Combine the Numerical Pipeline with Numeical Columns
    ("Ordinal Pipeline",ordinal_pipeline,ordinal_cols), ##Combine the Ordinal Pipeline with Ordinal Columns
    ("Nominal Pipeline",nominal_pieline,nominal_cols)   ##Combine the Nominal Pipeline with Nominal Columns
],
   n_jobs=-1,
   verbose=True,
   remainder="drop"
)

# %% [markdown]
# #### **End Pipeline**

# %%
final_pipeline=Pipeline(steps=[
    ("Preprocessing",Transfomers),  ##Preprocessing Step
    ("Resampling SMOTE",SMOTE(random_state=42)),  ##SMOTE Resampling Method
    ("Support Vector Classifier",SVC(kernel="linear",C=0.1,random_state=42)) ##Apply SVC
])

# %% [markdown]
# #### **Execute Pipeline**

# %%
final_pipeline.fit(X_train,Y_train)  ## Execute the Final Pipeline
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('Numerical Pipeline',
#                                                   Pipeline(steps=[('Scale',
#                                                                    StandardScaler())]),
#                                                   Index(['age', 'sleep_quality_index', 'brain_fog_level', 'physical_pain_score',
#        'stress_level', 'depression_phq9_score', 'fatigue_severity_scale_score',
#        'pem_duration_hours', 'hours_of_sleep_per_night'],
#       dtype='object')...
#                                                   ['work_status',
#                                                    'social_activity_level',
#                                                    'exercise_frequency']),
#                                                  ('Nominal Pipeline',
#                                                   Pipeline(steps=[('Nominal '
#                                                                    'Encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'pem_present',
#                                                    'meditation_or_mindfulness'])],
#                                    verbose=True)),
#                 ('Resampling SMOTE', SMOTE(random_state=42)),
#                 ('Support Vector Classifier',
#                  SVC(C=0.1, kernel='linear', random_state=42))])

# %% [markdown]
# ## **Model Evaluation**

# %%
Y_pred=final_pipeline.predict(X_test) ##get the prediction values

# %%
report_svc=classification_report(Y_test,Y_pred) ##get the classification report for predictions

# %%
Y_pred_train=final_pipeline.predict(X_train) ##get the preidction value for training set

# %%
report_svc_train=classification_report(Y_train,Y_pred_train) ##get the classification report for training

# %% [markdown]
# #### **Get the Evaluation Metrics for Testing Data**

# %%
f1_test=f1_score(Y_test,Y_pred,average='weighted') ##F1 score for testing data
precision_test=precision_score(Y_test,Y_pred,average="weighted") ##precision for testing data
accuracy_test=accuracy_score(Y_test,Y_pred) ## accuracy score for testing data
recall_test=recall_score(Y_test,Y_pred,average="weighted") ## recall score for testing data

# %%
# Print results
print(f"Accuracy:  {accuracy_test:.4f}")
print(f"Precision: {precision_test:.4f}")
print(f"F1 Score:  {f1_test:.4f}")
print(f"Recall Score: {recall_test:.4f}")
# Out:
# Accuracy:  0.9367
# Precision: 0.9453
# F1 Score:  0.9322
# Recall Score: 0.9367

# %% [markdown]
# #### **Get the Evaluation Metrics for Traning Data**

# %%
f1_train=f1_score(Y_train,Y_pred_train,average="weighted") ##F1 score for training data
precision_train=precision_score(Y_train,Y_pred_train,average="weighted") ## precision score for training data
accuracy_train=accuracy_score(Y_train,Y_pred_train) ## accuracy score for training data
recall_train=recall_score(Y_train,Y_pred_train,average="weighted") ##recall score for training data

# %%
# Print results
print(f"Accuracy:  {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"F1 Score:  {f1_train:.4f}")
print(f"Recall Score:{recall_train:.4f}")
# Out:
# Accuracy:  0.9157
# Precision: 0.9238
# F1 Score:  0.9108
# Recall Score:0.9157

# %%
### print the classification report for testing data
print(report_svc)
# Out:
#               precision    recall  f1-score   support
#
#         Both       1.00      0.65      0.79        54
#   Depression       1.00      1.00      1.00       125
#       ME/CFS       0.86      1.00      0.93       121
#
#     accuracy                           0.94       300
#    macro avg       0.95      0.88      0.90       300
# weighted avg       0.95      0.94      0.93       300

# %%
## print the classification report for training data
print(report_svc_train)
# Out:
#               precision    recall  f1-score   support
#
#         Both       0.95      0.64      0.76       148
#   Depression       1.00      1.00      1.00       276
#       ME/CFS       0.83      0.98      0.90       276
#
#     accuracy                           0.92       700
#    macro avg       0.93      0.87      0.89       700
# weighted avg       0.92      0.92      0.91       700

# %% [markdown]
# ## **Hyperparameter Tune using GridsearchCV**

# %%
param_grid = {
    'Support Vector Classifier__C': [0.001,0.01, 1, 10], ##variaous cost parameters
    'Support Vector Classifier__kernel': ['linear', 'rbf'], ##define kernels
    'Support Vector Classifier__gamma': ['scale', 'auto']  # relevant for 'rbf' kernel
}

# %%
grid_search=GridSearchCV(final_pipeline,param_grid=param_grid,cv=5,scoring="f1_weighted")

# %% [markdown]
# #### **Execute the Pipeline**

# %%
grid_search.fit(X_train,Y_train) ##execute the whole pipeline
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Preprocessing',
#                                         ColumnTransformer(n_jobs=-1,
#                                                           transformers=[('Numerical '
#                                                                          'Pipeline',
#                                                                          Pipeline(steps=[('Scale',
#                                                                                           StandardScaler())]),
#                                                                          Index(['age', 'sleep_quality_index', 'brain_fog_level', 'physical_pain_score',
#        'stress_level', 'depression_phq9_score', 'fatigue_severity_scale_score',
#        'pem_duration_hours', 'hours_of_sle...
#                                                                           'pem_present',
#                                                                           'meditation_or_mindfulness'])],
#                                                           verbose=True)),
#                                        ('Resampling SMOTE',
#                                         SMOTE(random_state=42)),
#                                        ('Support Vector Classifier',
#                                         SVC(C=0.1, kernel='linear',
#                                             random_state=42))]),
#              param_grid={'Support Vector Classifier__C': [0.001, 0.01, 1, 10],
#                          'Support Vector Classifier__gamma': ['scale', 'auto'],
#                          'Support Vector Classifier__kernel': ['linear',
#                                                                'rbf']},
#              scoring='f1_weighted')

# %% [markdown]
# #### **Best Model**

# %%
best_parameters=grid_search.best_params_
print(best_parameters)
# Out:
# {'Support Vector Classifier__C': 10, 'Support Vector Classifier__gamma': 'scale', 'Support Vector Classifier__kernel': 'linear'}

# %%
best_model=grid_search.best_estimator_

# %%
best_model
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('Numerical Pipeline',
#                                                   Pipeline(steps=[('Scale',
#                                                                    StandardScaler())]),
#                                                   Index(['age', 'sleep_quality_index', 'brain_fog_level', 'physical_pain_score',
#        'stress_level', 'depression_phq9_score', 'fatigue_severity_scale_score',
#        'pem_duration_hours', 'hours_of_sleep_per_night'],
#       dtype='object')...
#                                                   ['work_status',
#                                                    'social_activity_level',
#                                                    'exercise_frequency']),
#                                                  ('Nominal Pipeline',
#                                                   Pipeline(steps=[('Nominal '
#                                                                    'Encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'pem_present',
#                                                    'meditation_or_mindfulness'])],
#                                    verbose=True)),
#                 ('Resampling SMOTE', SMOTE(random_state=42)),
#                 ('Support Vector Classifier',
#                  SVC(C=10, kernel='linear', random_state=42))])

# %% [markdown]
# ## **Model Evaluation**

# %%
Y_pred_cv=best_model.predict(X_test) ##get the prediction values

# %%
report_svc_cv=classification_report(Y_test,Y_pred_cv) ##get the classification report for predictions

# %%
Y_pred_train_cv=best_model.predict(X_train) ##get the preidction value for training set

# %%
report_svc_train_cv=classification_report(Y_train,Y_pred_train_cv) ##get the classification report for training

# %% [markdown]
# #### **Get the Evaluation Metrics for Testing Data**

# %%
f1_test=f1_score(Y_test,Y_pred_cv,average='weighted') ##F1 score for testing data
precision_test=precision_score(Y_test,Y_pred_cv,average="weighted") ##precision for testing data
accuracy_test=accuracy_score(Y_test,Y_pred_cv) ## accuracy score for testing data
recall_test=recall_score(Y_test,Y_pred_cv,average="weighted") ## recall score for testing data

# %%
# Print results
print(f"Accuracy:  {accuracy_test:.4f}")
print(f"Precision: {precision_test:.4f}")
print(f"F1 Score:  {f1_test:.4f}")
print(f"Recall Score: {recall_test:.4f}")
# Out:
# Accuracy:  0.9967
# Precision: 0.9967
# F1 Score:  0.9967
# Recall Score: 0.9967

# %% [markdown]
# #### **Get the Evaluation Metrics for Training Data**

# %%
f1_train=f1_score(Y_train,Y_pred_train_cv,average="weighted") ##F1 score for training data
precision_train=precision_score(Y_train,Y_pred_train_cv,average="weighted") ## precision score for training data
accuracy_train=accuracy_score(Y_train,Y_pred_train_cv) ## accuracy score for training data
recall_train=recall_score(Y_train,Y_pred_train_cv,average="weighted") ##recall score for training data

# %%
# Print results
print(f"Accuracy:  {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"F1 Score:  {f1_train:.4f}")
print(f"Recall Score:{recall_train:.4f}")
# Out:
# Accuracy:  0.9886
# Precision: 0.9889
# F1 Score:  0.9886
# Recall Score:0.9886

# %%
### print the classification report for testing data
print(report_svc_cv)
# Out:
#               precision    recall  f1-score   support
#
#         Both       0.98      1.00      0.99        54
#   Depression       1.00      1.00      1.00       125
#       ME/CFS       1.00      0.99      1.00       121
#
#     accuracy                           1.00       300
#    macro avg       0.99      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300

# %%
## print the classification report for training data
print(report_svc_train_cv)
# Out:
#               precision    recall  f1-score   support
#
#         Both       0.95      0.99      0.97       148
#   Depression       1.00      1.00      1.00       276
#       ME/CFS       1.00      0.97      0.99       276
#
#     accuracy                           0.99       700
#    macro avg       0.98      0.99      0.99       700
# weighted avg       0.99      0.99      0.99       700

# %% [markdown]
# ## **Hyperparameter Tune using Optuna**

# %% [markdown]
# #### **Import Required Libraries**

# %%
import optuna
from sklearn.model_selection import cross_val_score

# %% [markdown]
# #### **Define the Objective Function**

# %%
def objective(trials):
    ##define parameters 
    C=trials.suggest_float("C",0.1,100,log=True)
    kernel=trials.suggest_categorical("kernel",["linear","rbf","poly"])
    gamma=trials.suggest_categorical("gamma",["scale","auto"])

    ##Build the pipeline
    pipeline_optuna=Pipeline(steps=[
        ("Preprocessing",Transfomers),
        ("Resampling SMOTE",SMOTE(random_state=42)),
        ("Support Vector Classifier",SVC(random_state=42,C=C,gamma=gamma,kernel=kernel))
    ])

    ##cross validation score
    score=cross_val_score(pipeline_optuna,X_train,Y_train,cv=5,scoring="f1_weighted")
    return score.mean()

# %% [markdown]
# #### **Run the Optimizer**

# %%
study=optuna.create_study(
    study_name="svc_model"
    ,direction="maximize")
study.optimize(objective,n_trials=50)
# Out:
# [I 2025-07-24 21:22:31,181] A new study created in memory with name: svc_model
# [I 2025-07-24 21:22:31,424] Trial 0 finished with value: 0.8828536777885748 and parameters: {'C': 59.32134972669979, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 0 with value: 0.8828536777885748.
# [I 2025-07-24 21:22:31,659] Trial 1 finished with value: 0.976856069952093 and parameters: {'C': 0.8183155902865907, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 1 with value: 0.976856069952093.
# [I 2025-07-24 21:22:31,889] Trial 2 finished with value: 0.9886505038683688 and parameters: {'C': 1.6863484954609287, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:32,111] Trial 3 finished with value: 0.9886505038683688 and parameters: {'C': 7.370379214385159, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:32,346] Trial 4 finished with value: 0.8828536777885748 and parameters: {'C': 44.333901708402834, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:32,557] Trial 5 finished with value: 0.9158186421195257 and parameters: {'C': 0.5666603682686381, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:32,861] Trial 6 finished with value: 0.8984240543072252 and parameters: {'C': 56.0916739889871, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:33,102] Trial 7 finished with value: 0.9886505038683688 and parameters: {'C': 3.10630260495147, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:33,342] Trial 8 finished with value: 0.9886505038683688 and parameters: {'C': 20.765060301659776, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:33,567] Trial 9 finished with value: 0.9886505038683688 and parameters: {'C': 5.812120444838595, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:33,835] Trial 10 finished with value: 0.8905580171354084 and parameters: {'C': 0.17866854004862354, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:34,060] Trial 11 finished with value: 0.9886505038683688 and parameters: {'C': 5.908700685049491, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:34,288] Trial 12 finished with value: 0.9886505038683688 and parameters: {'C': 1.6636720574740829, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:34,542] Trial 13 finished with value: 0.8871227048846979 and parameters: {'C': 10.137693567106986, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:34,764] Trial 14 finished with value: 0.8791286889853158 and parameters: {'C': 1.6202018848292674, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:34,982] Trial 15 finished with value: 0.9171556704622915 and parameters: {'C': 0.25770360569263195, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:35,216] Trial 16 finished with value: 0.9886505038683688 and parameters: {'C': 12.457570902589143, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:35,450] Trial 17 finished with value: 0.9886505038683688 and parameters: {'C': 2.4517236873437085, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:35,709] Trial 18 finished with value: 0.9021230981185526 and parameters: {'C': 0.5774302414176796, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:35,944] Trial 19 finished with value: 0.8828536777885748 and parameters: {'C': 28.262913820787773, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:36,330] Trial 20 finished with value: 0.9886505038683688 and parameters: {'C': 99.30632352991014, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:36,554] Trial 21 finished with value: 0.9886505038683688 and parameters: {'C': 4.165170835705765, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:36,847] Trial 22 finished with value: 0.9886505038683688 and parameters: {'C': 2.510759428596681, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:37,073] Trial 23 finished with value: 0.9886505038683688 and parameters: {'C': 9.89221561755936, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:37,300] Trial 24 finished with value: 0.9813382509039419 and parameters: {'C': 1.138682989749418, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:37,526] Trial 25 finished with value: 0.9886505038683688 and parameters: {'C': 3.874070985922582, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:37,751] Trial 26 finished with value: 0.9886505038683688 and parameters: {'C': 6.282890643136369, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:37,965] Trial 27 finished with value: 0.9158186421195257 and parameters: {'C': 0.4108917812065507, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:38,185] Trial 28 finished with value: 0.8789887894237658 and parameters: {'C': 1.5589849713868238, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:38,454] Trial 29 finished with value: 0.8928501628385581 and parameters: {'C': 17.264293852291207, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:38,685] Trial 30 finished with value: 0.8867410783864924 and parameters: {'C': 2.710355496782012, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:38,926] Trial 31 finished with value: 0.9886505038683688 and parameters: {'C': 21.742335401837234, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:39,169] Trial 32 finished with value: 0.9886505038683688 and parameters: {'C': 33.473817761289375, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:39,399] Trial 33 finished with value: 0.9886505038683688 and parameters: {'C': 7.453258374130405, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:39,633] Trial 34 finished with value: 0.9886505038683688 and parameters: {'C': 16.69382161282745, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:39,853] Trial 35 finished with value: 0.9798245596975971 and parameters: {'C': 0.8984701084980051, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:40,079] Trial 36 finished with value: 0.9886505038683688 and parameters: {'C': 3.4581029020573557, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:40,291] Trial 37 finished with value: 0.9117433827486685 and parameters: {'C': 0.1066992217823763, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:40,546] Trial 38 finished with value: 0.888449494983373 and parameters: {'C': 4.884693473475343, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:40,784] Trial 39 finished with value: 0.8814921411450408 and parameters: {'C': 43.62465722056975, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:41,035] Trial 40 finished with value: 0.9886505038683688 and parameters: {'C': 9.233448146277686, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:41,268] Trial 41 finished with value: 0.9886505038683688 and parameters: {'C': 13.847425672143519, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:41,559] Trial 42 finished with value: 0.9886505038683688 and parameters: {'C': 2.012081484508953, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:41,785] Trial 43 finished with value: 0.9886505038683688 and parameters: {'C': 5.615713920358447, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:42,019] Trial 44 finished with value: 0.9886505038683688 and parameters: {'C': 8.125993532752194, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:42,231] Trial 45 finished with value: 0.9828323871479965 and parameters: {'C': 1.2202717189252477, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:42,489] Trial 46 finished with value: 0.8957257298402803 and parameters: {'C': 3.1798723968415428, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:42,727] Trial 47 finished with value: 0.9886505038683688 and parameters: {'C': 11.966854052737302, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:42,974] Trial 48 finished with value: 0.9886505038683688 and parameters: {'C': 23.572237293088676, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 2 with value: 0.9886505038683688.
# [I 2025-07-24 21:22:43,194] Trial 49 finished with value: 0.8748317230981604 and parameters: {'C': 0.6233904283439734, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 2 with value: 0.9886505038683688.

# %% [markdown]
# #### **Best Model**

# %%
best_model_optuna=study.best_params
print(f"Best Params:{best_model_optuna}")
# Out:
# Best Params:{'C': 1.6863484954609287, 'kernel': 'linear', 'gamma': 'auto'}

# %% [markdown]
# #### **Rebuild the Pipeline with Best Parameters**

# %%
best_pipeline=Pipeline(steps=[
        ("Preprocessing",Transfomers),
        ("Resampling SMOTE",SMOTE(random_state=42)),
        ("Support Vector Classifier",SVC(random_state=42,**best_model_optuna))
    ])

# %% [markdown]
# #### **Train the Model with Best Parameters**

# %%
best_pipeline.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('Numerical Pipeline',
#                                                   Pipeline(steps=[('Scale',
#                                                                    StandardScaler())]),
#                                                   Index(['age', 'sleep_quality_index', 'brain_fog_level', 'physical_pain_score',
#        'stress_level', 'depression_phq9_score', 'fatigue_severity_scale_score',
#        'pem_duration_hours', 'hours_of_sleep_per_night'],
#       dtype='object')...
#                                                    'exercise_frequency']),
#                                                  ('Nominal Pipeline',
#                                                   Pipeline(steps=[('Nominal '
#                                                                    'Encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'pem_present',
#                                                    'meditation_or_mindfulness'])],
#                                    verbose=True)),
#                 ('Resampling SMOTE', SMOTE(random_state=42)),
#                 ('Support Vector Classifier',
#                  SVC(C=1.6863484954609287, gamma='auto', kernel='linear',
#                      random_state=42))])

# %% [markdown]
# #### **Evaluate the Model**

# %%
Y_pred_optuna=best_pipeline.predict(X_test) ##get the prediction values

# %%
report_svc_optuna=classification_report(Y_test,Y_pred_optuna) ##get the classification report for predictions

# %%
Y_pred_train_optuna=best_pipeline.predict(X_train) ##get the preidction value for training set

# %%
report_svc_train_optuna=classification_report(Y_train,Y_pred_train_optuna) ##get the classification report for training

# %% [markdown]
# #### **Get the Evaluation Metrics for Testing Data**

# %%
f1_test=f1_score(Y_test,Y_pred_optuna,average='weighted') ##F1 score for testing data
precision_test=precision_score(Y_test,Y_pred_optuna,average="weighted") ##precision for testing data
accuracy_test=accuracy_score(Y_test,Y_pred_optuna) ## accuracy score for testing data
recall_test=recall_score(Y_test,Y_pred_optuna,average="weighted") ## recall score for testing data

# %%
# Print results
print(f"Accuracy:  {accuracy_test:.4f}")
print(f"Precision: {precision_test:.4f}")
print(f"F1 Score:  {f1_test:.4f}")
print(f"Recall Score:{recall_test:.4f}")
# Out:
# Accuracy:  0.9967
# Precision: 0.9967
# F1 Score:  0.9967
# Recall Score:0.9967

# %% [markdown]
# #### **Get the Evaluation Metrics for Training Data**

# %%
f1_train=f1_score(Y_train,Y_pred_train_optuna,average="weighted") ##F1 score for training data
precision_train=precision_score(Y_train,Y_pred_train_optuna,average="weighted") ## precision score for training data
accuracy_train=accuracy_score(Y_train,Y_pred_train_optuna) ## accuracy score for training data
recall_train=recall_score(Y_train,Y_pred_train_optuna,average="weighted") ##recall score for training data

# %%
# Print results
print(f"Accuracy:  {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"F1 Score:  {f1_train:.4f}")
print(f"Recall Score:{recall_train:.4f}")
# Out:
# Accuracy:  0.9886
# Precision: 0.9889
# F1 Score:  0.9886
# Recall Score:0.9886

# %% [markdown]
# ## **Model Deployment using Mlflow**

# %%
import mlflow

# %%
import mlflow.sklearn
import mlflow.sklearn


mlflow.set_tracking_uri("http://127.0.0.1:5000/")
mlflow.set_experiment("Support-Vector-Classifier")

with mlflow.start_run(run_name="Support Vector Classifier"):
    ##Before Hyperparameter Tune
    params={
        "kernel":"linear",
        "C":0.1
    }
    mlflow.log_params(params)
    metrics_1={
        "accuracy":accuracy_score(Y_test,Y_pred),
        "f1-score":f1_score(Y_test,Y_pred,average='weighted'),
        "precision":precision_score(Y_test,Y_pred,average="weighted") ,
        "recall":recall_score(Y_test,Y_pred,average="weighted")
    }
    for key,value in metrics_1.items():
        mlflow.log_metric(key,value)
    
    mlflow.sklearn.log_model(final_pipeline,"Support Vector Classifier")
    #############################################################################
    
with mlflow.start_run(run_name="Support Vector Classifier with Grid SearchCV"):
    ### After Grid Search CV
    mlflow.log_params(best_parameters)
    metrics_2={
      "accuracy":accuracy_score(Y_test,Y_pred_cv),
      "f1-score":f1_score(Y_test,Y_pred_cv,average='weighted'),
      "precision":precision_score(Y_test,Y_pred_cv,average="weighted"),
      "recall":recall_score(Y_test,Y_pred_cv,average="weighted") 
    }
    
    for key,value in metrics_2.items():
        mlflow.log_metric(key,value)

    mlflow.sklearn.log_model(best_model,"Support Vector Classifier with Grid SearchCV")
    #######################################################################################

with mlflow.start_run(run_name="Support Vector Classifier with Optuna"):
    ## After Optuna result
    mlflow.log_params(best_model_optuna)
    metrics_3={
        "accuracy":accuracy_score(Y_test,Y_pred_optuna),
        "f1-score":f1_score(Y_test,Y_pred_optuna,average='weighted'),
        "precision":precision_score(Y_test,Y_pred_optuna,average="weighted"),
        "recall":recall_score(Y_test,Y_pred_optuna,average="weighted")
    }

    for key, value in metrics_3.items():
        mlflow.log_metric(key, value)
    mlflow.sklearn.log_model(best_pipeline,"Support Vector Classifier with Optuna")
# Out:
# 2025/07/24 21:31:15 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/24 21:31:19 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Support Vector Classifier at: http://127.0.0.1:5000/#/experiments/115928509220578129/runs/db2c9218ce1e4cbc856980fbeb42d519
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/115928509220578129
# 2025/07/24 21:31:20 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/24 21:31:25 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Support Vector Classifier with Grid SearchCV at: http://127.0.0.1:5000/#/experiments/115928509220578129/runs/8cc9c312192c41b89b840587a0d7007a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/115928509220578129
# 2025/07/24 21:31:25 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/24 21:31:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Support Vector Classifier with Optuna at: http://127.0.0.1:5000/#/experiments/115928509220578129/runs/aa7b9a5f063045e7a0c9fe50037eb810
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/115928509220578129

# %% [markdown]
# #### **Register the Model**

# %%
model_name="Support Vector Classifier with Grid SearchCV"
run_id=input("Enter the Model Run ID:")
model_uri=f"runs:/{run_id}/{model_name}"

with mlflow.start_run(run_id=run_id):
    mlflow.register_model(model_uri=model_uri,name=model_name)
# Out:
# Successfully registered model 'Support Vector Classifier with Grid SearchCV'.
# 2025/07/24 21:33:00 WARNING mlflow.tracking._model_registry.fluent: Run with id 8cc9c312192c41b89b840587a0d7007a has no artifacts at artifact path 'Support Vector Classifier with Grid SearchCV', registering model based on models:/m-58f9bfaa24a14fe48cba9702a94723bf instead
# 2025/07/24 21:33:00 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Support Vector Classifier with Grid SearchCV, version 1
# Created version '1' of model 'Support Vector Classifier with Grid SearchCV'.
# 🏃 View run Support Vector Classifier with Grid SearchCV at: http://127.0.0.1:5000/#/experiments/115928509220578129/runs/8cc9c312192c41b89b840587a0d7007a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/115928509220578129

# %% [markdown]
# ## **Trust Model**

# %% [markdown]
# ### **XAI Techniques(SHAP)**

# %% [markdown]
# #### **Import Required Libraries**

# %%
import shap

# %%
#### Exctract the SVC model from the pipeline
svc_model=best_model.named_steps["Support Vector Classifier"]

##Extract the preprocess data from the pipeline
X_train_encode=best_model.named_steps["Preprocessing"].fit_transform(X_train)
X_test_encode=best_model.named_steps["Preprocessing"].transform(X_test)

# %%
####################################################################################
ordinal_cols=best_model.named_steps["Preprocessing"].named_transformers_["Ordinal Pipeline"].get_feature_names_out(ordinal_cols)
nominal_cols=best_model.named_steps["Preprocessing"].named_transformers_["Nominal Pipeline"].get_feature_names_out(nominal_cols)
feature_names=np.concatenate([num_cols,ordinal_cols,nominal_cols])

# %%
X_train_encode=pd.DataFrame(X_train_encode,columns=feature_names)
X_test_encode=pd.DataFrame(X_test_encode,columns=feature_names)

# %% [markdown]
# #### **Define the SHAP objective**

# %%
explainer=shap.LinearExplainer(svc_model,X_train_encode,feature_perturbation="interventional") #define SHAP objective

# %% [markdown]
# #### **Identifying the Classes**

# %%
print(svc_model.classes_)

## 0 with Both,1 with Depresssion and 2 with ME/CFS
# Out:
# ['Both' 'Depression' 'ME/CFS']

# %% [markdown]
# #### **Get the SHAP values**

# %%
shape_values=explainer(X_test_encode) ##get the SHAPE values
print(np.shape(shape_values))  ##shape of the SHAP values
# Out:
# (300, 18, 3)

# %%
predict=svc_model.predict(X_test_encode)
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(

# %%
# Define mapping
label_map = {'Both': 0, 'Depression': 1, 'ME/CFS': 2}
predict_series = pd.Series(predict)
predict = predict_series.map(label_map).values

# %%
new_shape_values=[]
for i,pred in enumerate(predict):
    ##get the values for predicted class
    new_shape_values.append(shape_values.values[i][:,pred])

##replce the shap values
shape_values.values=np.array(new_shape_values)
print(shape_values.shape)
# Out:
# (300, 18)

# %% [markdown]
# #### **Feature Importance Plot**

# %%
shap.plots.bar(shape_values) ##average contribution for the predicted class

# %% [markdown]
# #### **Most Critical Variables for prediction Depression Score and and Pem Present**

# %% [markdown]
# #### **Beeswarm Plot**

# %%
shap.plots.beeswarm(shape_values)

# %% [markdown]
# ## **Get the Most Critical Variables and Fit the SVC Model again**

# %% [markdown]
# #### **Arrange the X_train,X_test,Y_train,Y_test**

# %%
X_train_=X_train[["depression_phq9_score","pem_present"]]
X_test_=X_test[["depression_phq9_score","pem_present"]]

# %%
print(f"Shape of the new Training set:{X_train_.shape,Y_train.shape}")
print(f"Shape of the new Testing set:{X_test_.shape,Y_test.shape}")
# Out:
# Shape of the new Training set:((700, 2), (700,))
# Shape of the new Testing set:((300, 2), (300,))

# %% [markdown]
# #### **Define the new Pipeline**

# %%
numerical_pipeline=Pipeline(steps=[
    ("Scale",StandardScaler())                ##Numberical varaibles pipeline
])
nominal_pieline=Pipeline(steps=[
    ("Nominal Encoder",OneHotEncoder(sparse_output=False,handle_unknown="ignore"))  ##Nominal variable pipeline
])

# %% [markdown]
# #### **Combine the new Pipeline**

# %%
Transfomers=ColumnTransformer(transformers=[
    ("Numerical Pipeline",numerical_pipeline,["depression_phq9_score"]), ##Combine the Numerical Pipeline with Numeical Columns
    ("Nominal Pipeline",nominal_pieline,["pem_present"])   ##Combine the Nominal Pipeline with Nominal Columns
],
   n_jobs=-1,
   verbose=True,
   remainder="drop"
)

# %% [markdown]
# #### **End Pipeline**

# %%
   ##Build the pipeline
pipeline_final=Pipeline(steps=[
        ("Preprocessing",Transfomers),
        ("Resampling SMOTE",SMOTE(random_state=42)),
        ("Support Vector Classifier",SVC(random_state=42,C=10,gamma="scale",kernel="linear"))
])

# %% [markdown]
# #### **Run Pipeline**

# %%
pipeline_final.fit(X_train_,Y_train)
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('Numerical Pipeline',
#                                                   Pipeline(steps=[('Scale',
#                                                                    StandardScaler())]),
#                                                   ['depression_phq9_score']),
#                                                  ('Nominal Pipeline',
#                                                   Pipeline(steps=[('Nominal '
#                                                                    'Encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['pem_present'])],
#                                    verbose=True)),
#                 ('Resampling SMOTE', SMOTE(random_state=42)),
#                 ('Support Vector Classifier',
#                  SVC(C=10, kernel='linear', random_state=42))])

# %% [markdown]
# #### **Evaluate the Model**

# %%
Y_pred_cv_new=pipeline_final.predict(X_test_) ##get the prediction values
report_svc_cv_new=classification_report(Y_test,Y_pred_cv_new) ##get the classification report for predictions
Y_pred_train_cv_new=pipeline_final.predict(X_train_) ##get the preidction value for training set
report_svc_train_cv_new=classification_report(Y_train,Y_pred_train_cv_new) ##get the classification report for training

# %% [markdown]
# #### **Get the Evaluation Metrics for Testing Data**

# %%
f1_test=f1_score(Y_test,Y_pred_cv_new,average='weighted') ##F1 score for testing data
precision_test=precision_score(Y_test,Y_pred_cv_new,average="weighted") ##precision for testing data
accuracy_test=accuracy_score(Y_test,Y_pred_cv_new) ## accuracy score for testing data
recall_test=recall_score(Y_test,Y_pred_cv_new,average="weighted") ## recall score for testing data

# %%
# Print results
print(f"Accuracy:  {accuracy_test:.4f}")
print(f"Precision: {precision_test:.4f}")
print(f"F1 Score:  {f1_test:.4f}")
print(f"Recall Score:{recall_test:.4f}")
# Out:
# Accuracy:  0.9967
# Precision: 0.9967
# F1 Score:  0.9967
# Recall Score:0.9967

# %% [markdown]
# #### **Get the Evaluation Metrics for Training Data**

# %%
f1_train=f1_score(Y_train,Y_pred_train_cv_new,average="weighted") ##F1 score for training data
precision_train=precision_score(Y_train,Y_pred_train_cv_new,average="weighted") ## precision score for training data
accuracy_train=accuracy_score(Y_train,Y_pred_train_cv_new) ## accuracy score for training data
recall_train=recall_score(Y_train,Y_pred_train_cv_new,average="weighted") ##recall score for training data

# %%
# Print results
print(f"Accuracy:  {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"F1 Score:  {f1_train:.4f}")
print(f"Recall Score:{recall_train:.4f}")
# Out:
# Accuracy:  0.9886
# Precision: 0.9889
# F1 Score:  0.9886
# Recall Score:0.9886

# %%
##print the classification report for testing data
print(report_svc_cv_new)
# Out:
#               precision    recall  f1-score   support
#
#         Both       0.98      1.00      0.99        54
#   Depression       1.00      1.00      1.00       125
#       ME/CFS       1.00      0.99      1.00       121
#
#     accuracy                           1.00       300
#    macro avg       0.99      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300

# %%
##print the classification report for training data
print(report_svc_train_cv_new)
# Out:
#               precision    recall  f1-score   support
#
#         Both       0.95      0.99      0.97       148
#   Depression       1.00      1.00      1.00       276
#       ME/CFS       1.00      0.97      0.99       276
#
#     accuracy                           0.99       700
#    macro avg       0.98      0.99      0.99       700
# weighted avg       0.99      0.99      0.99       700

# %% [markdown]
# ## **Save the Train Model using Pickle**

# %%
import pickle

# %%
with open("C:\\UOC pdf\\4th Year\\Machine Learning-02\\Data-Analysis-Project-2\\product\\train_model.pkl","wb") as f:
    pickle.dump(pipeline_final.named_steps["Support Vector Classifier"],f)

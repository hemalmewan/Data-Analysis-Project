# %% [markdown]
# ## **Import Required Libraries**

# %%
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report,f1_score,accuracy_score,precision_score,recall_score
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder,StandardScaler
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore",category=FutureWarning)

# %% [markdown]
# ## **Load the Datasets**

# %%
train_data=pd.read_csv("C:/UOC pdf/4th Year/Machine Learning-02/Data-Analysis-1/data/train_data.csv")
test_data=pd.read_csv("C:/UOC pdf/4th Year/Machine Learning-02/Data-Analysis-1/data/test_data.csv")

# %%
train_data=train_data.drop(columns=["Unnamed: 0"],axis=1)
test_data=test_data.drop(columns=["Unnamed: 0"],axis=1)

# %% [markdown]
# ## **Split X_train,Y_train,X_test,Y_test**

# %%
X_train=train_data.drop(columns=["diagnosis"],axis=1)
Y_train=train_data["diagnosis"]
X_test=test_data.drop(columns=["diagnosis"],axis=1)
Y_test=test_data["diagnosis"]

# %%
print(f"Shape of the Training set:{X_train.shape,Y_train.shape}")
print(f"Shape of  the Testing set:{X_test.shape,Y_test.shape}")
# Out:
# Shape of the Training set:((700, 15), (700,))
# Shape of  the Testing set:((300, 15), (300,))

# %% [markdown]
# ## **Build the Pipeline**

# %%
num_cols=X_train.select_dtypes(include="number").columns  ##get the all numerical column names
cat_cols=X_train.select_dtypes(include=["object","category"]).columns ##get the all categorical column names

# %%
nominal_cols=["gender","pem_present","meditation_or_mindfulness"] ##nominal columns
ordinal_cols=["work_status","social_activity_level","exercise_frequency"] ##ordinal columns

# %% [markdown]
# #### **Define the Pipeline**

# %%
ordinal_pipeline=Pipeline(steps=[
    ("Ordinal Encoder",OrdinalEncoder())      ##Ordinal variable pipeline
])
nominal_pipeline=Pipeline(steps=[
    ("Nominal Encoder",OneHotEncoder(sparse_output=False,handle_unknown="ignore"))  ##Nominal variable pipeline
])

# %% [markdown]
# #### **Combine Pipeline**

# %%
Transfomers=ColumnTransformer(transformers=[
    ("Ordinal Pipeline",ordinal_pipeline,ordinal_cols), ##Combine the Ordinal Pipeline with Ordinal Columns
    ("Nominal Pipeline",nominal_pipeline,nominal_cols)   ##Combine the Nominal Pipeline with Nominal Columns
],
   n_jobs=-1,
   verbose=True,
   remainder="drop"
)

# %% [markdown]
# #### **End Pipeline**

# %%
final_pipeline=Pipeline(steps=[
    ("Preprocessing",Transfomers),  ##Preprocessing Step
    ("Resampling SMOTE",SMOTE(random_state=42)),  ##SMOTE Resampling Method
    ("XGB Classifier",XGBClassifier()) ##Apply XGB Classifier
])

# %% [markdown]
# #### **Make the Reponse variable as 0,1,2**

# %%
Y_train=pd.DataFrame(Y_train)
Y_test=pd.DataFrame(Y_test)

# %%
## 1.Resposne variable
# Replace 0.0 with 'Both', 1.0 with 'Depression' and 2.0 with ME/CFS
Y_train["diagnosis"] = Y_train["diagnosis"].map({"Both":0,"Depression":1,"ME/CFS":2})
Y_test["diagnosis"] = Y_test["diagnosis"].map({"Both":0,"Depression":1,"ME/CFS":2})

# %% [markdown]
# #### **Execute Pipeline**

# %%
final_pipeline.fit(X_train,Y_train)  ## Execute the Final Pipeline
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('Ordinal Pipeline',
#                                                   Pipeline(steps=[('Ordinal '
#                                                                    'Encoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['work_status',
#                                                    'social_activity_level',
#                                                    'exercise_frequency']),
#                                                  ('Nominal Pipeline',
#                                                   Pipeline(steps=[('Nominal '
#                                                                    'Encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'pem_presen...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %% [markdown]
# ## **Model Evaluation**

# %%
Y_pred=final_pipeline.predict(X_test) ##get the prediction values

# %%
report_xgb=classification_report(Y_test,Y_pred) ##get the classification report for predictions

# %%
Y_pred_train=final_pipeline.predict(X_train) ##get the preidction value for training set

# %%
report_xgb_train=classification_report(Y_train,Y_pred_train) ##get the classification report for training

# %% [markdown]
# #### **Get the Evaluation Metrics for Testing Data**

# %%
f1_test=f1_score(Y_test,Y_pred,average='weighted') ##F1 score for testing data
precision_test=precision_score(Y_test,Y_pred,average="weighted") ##precision for testing data
accuracy_test=accuracy_score(Y_test,Y_pred) ## accuracy score for testing data
recall_test=recall_score(Y_test,Y_pred,average="weighted") ## recall score for testing data

# %%
# Print results
print(f"Accuracy:  {accuracy_test:.4f}")
print(f"Precision: {precision_test:.4f}")
print(f"F1 Score:  {f1_test:.4f}")
print(f"Recall Score: {recall_test:.4f}")
# Out:
# Accuracy:  0.7967
# Precision: 0.7895
# F1 Score:  0.7925
# Recall Score: 0.7967

# %% [markdown]
# #### **Get the Evaluation Metrics for Training Data**

# %%
f1_train=f1_score(Y_train,Y_pred_train,average="weighted") ##F1 score for training data
precision_train=precision_score(Y_train,Y_pred_train,average="weighted") ## precision score for training data
accuracy_train=accuracy_score(Y_train,Y_pred_train) ## accuracy score for training data
recall_train=recall_score(Y_train,Y_pred_train,average="weighted") ##recall score for training data

# %%
# Print results
print(f"Accuracy:  {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"F1 Score:  {f1_train:.4f}")
print(f"Recall Score:{recall_train:.4f}")
# Out:
# Accuracy:  0.8971
# Precision: 0.8960
# F1 Score:  0.8963
# Recall Score:0.8971

# %%
### print the classification report for testing data
print(report_xgb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.37      0.40        54
#            1       1.00      1.00      1.00       125
#            2       0.73      0.78      0.76       121
#
#     accuracy                           0.80       300
#    macro avg       0.72      0.72      0.72       300
# weighted avg       0.79      0.80      0.79       300

# %%
## print the classification report for training data
print(report_xgb_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75       148
#            1       1.00      1.00      1.00       276
#            2       0.86      0.89      0.87       276
#
#     accuracy                           0.90       700
#    macro avg       0.88      0.87      0.87       700
# weighted avg       0.90      0.90      0.90       700

# %% [markdown]
# ## **Hyperparameter Tune using Grid SearchCV**

# %%
param_grid = {
    'XGB Classifier__n_estimators': [100, 200, 300],
    'XGB Classifier__max_depth': [3, 5, 7, 10],
    'XGB Classifier__learning_rate': [0.01, 0.05, 0.1, 0.2],
    'XGB Classifier__subsample': [0.6, 0.8, 1.0],
    'XGB Classifier__colsample_bytree': [0.6, 0.8, 1.0],
    'XGB Classifier__gamma': [0, 1, 5],
}

# %%
grid_search=GridSearchCV(final_pipeline,param_grid=param_grid,cv=5,scoring="f1_weighted")

# %% [markdown]
# #### **Execute the Pipeline**

# %%
grid_search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Preprocessing',
#                                         ColumnTransformer(n_jobs=-1,
#                                                           transformers=[('Ordinal '
#                                                                          'Pipeline',
#                                                                          Pipeline(steps=[('Ordinal '
#                                                                                           'Encoder',
#                                                                                           OrdinalEncoder())]),
#                                                                          ['work_status',
#                                                                           'social_activity_level',
#                                                                           'exercise_frequency']),
#                                                                         ('Nominal '
#                                                                          'Pipeline',
#                                                                          Pipeline(steps=[('Nominal '
#                                                                                           'Encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         sparse_output...
#                                                       multi_strategy=None,
#                                                       n_estimators=None,
#                                                       n_jobs=None,
#                                                       num_parallel_tree=None, ...))]),
#              param_grid={'XGB Classifier__colsample_bytree': [0.6, 0.8, 1.0],
#                          'XGB Classifier__gamma': [0, 1, 5],
#                          'XGB Classifier__learning_rate': [0.01, 0.05, 0.1,
#                                                            0.2],
#                          'XGB Classifier__max_depth': [3, 5, 7, 10],
#                          'XGB Classifier__n_estimators': [100, 200, 300],
#                          'XGB Classifier__subsample': [0.6, 0.8, 1.0]},
#              scoring='f1_weighted')

# %% [markdown]
# #### **Best Model**

# %%
best_parameters=grid_search.best_params_
print(best_parameters)
# Out:
# {'XGB Classifier__colsample_bytree': 0.6, 'XGB Classifier__gamma': 0, 'XGB Classifier__learning_rate': 0.2, 'XGB Classifier__max_depth': 10, 'XGB Classifier__n_estimators': 200, 'XGB Classifier__subsample': 0.6}

# %%
best_model=grid_search.best_estimator_

# %%
best_model
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('Ordinal Pipeline',
#                                                   Pipeline(steps=[('Ordinal '
#                                                                    'Encoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['work_status',
#                                                    'social_activity_level',
#                                                    'exercise_frequency']),
#                                                  ('Nominal Pipeline',
#                                                   Pipeline(steps=[('Nominal '
#                                                                    'Encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'pem_presen...
#                                feature_types=None, feature_weights=None,
#                                gamma=0, grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=0.2,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=10, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=200, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %% [markdown]
# ## **Model Evaluation**

# %%
Y_pred_cv=best_model.predict(X_test) ##get the prediction values

# %%
report_xgb_cv=classification_report(Y_test,Y_pred_cv) ##get the classification report for predictions

# %%
Y_pred_train_cv=best_model.predict(X_train) ##get the preidction value for training set

# %%
report_xgb_train_cv=classification_report(Y_train,Y_pred_train_cv) ##get the classification report for training

# %% [markdown]
# #### **Get the Evaluation Metrics for Testing Data**

# %%
f1_test=f1_score(Y_test,Y_pred_cv,average='weighted') ##F1 score for testing data
precision_test=precision_score(Y_test,Y_pred_cv,average="weighted") ##precision for testing data
accuracy_test=accuracy_score(Y_test,Y_pred_cv) ## accuracy score for testing data
recall_test=recall_score(Y_test,Y_pred_cv,average="weighted") ## recall score for testing data

# %%
# Print results
print(f"Accuracy:  {accuracy_test:.4f}")
print(f"Precision: {precision_test:.4f}")
print(f"F1 Score:  {f1_test:.4f}")
print(f"Recall Score: {recall_test:.4f}")
# Out:
# Accuracy:  0.8033
# Precision: 0.7926
# F1 Score:  0.7965
# Recall Score: 0.8033

# %% [markdown]
# #### **Get the Evaluation Metrics for Training Data**

# %%
f1_train=f1_score(Y_train,Y_pred_train_cv,average="weighted") ##F1 score for training data
precision_train=precision_score(Y_train,Y_pred_train_cv,average="weighted") ## precision score for training data
accuracy_train=accuracy_score(Y_train,Y_pred_train_cv) ## accuracy score for training data
recall_train=recall_score(Y_train,Y_pred_train_cv,average="weighted") ##recall score for training data

# %%
# Print results
print(f"Accuracy:  {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"F1 Score:  {f1_train:.4f}")
print(f"Recall Score:{recall_train:.4f}")
# Out:
# Accuracy:  0.8914
# Precision: 0.8898
# F1 Score:  0.8894
# Recall Score:0.8914

# %% [markdown]
# ## **Hyperparameter Tune Using Optuna**

# %%
import optuna
from sklearn.model_selection import cross_val_score

# %%
def objective(trials):
    ##define parameters 
    params = {
        "n_estimators": trials.suggest_int("n_estimators", 100, 500),
        "max_depth": trials.suggest_int("max_depth", 3, 15),
        "learning_rate": trials.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "subsample": trials.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trials.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trials.suggest_float("gamma", 0, 5),
        "reg_alpha": trials.suggest_float("reg_alpha", 1e-8, 10.0, log=True),
        "reg_lambda": trials.suggest_float("reg_lambda", 1e-8, 10.0, log=True),
        "min_child_weight": trials.suggest_int("min_child_weight", 1, 20),
        "scale_pos_weight": trials.suggest_float("scale_pos_weight", 1, 10),
        "n_jobs": -1,
        "use_label_encoder": False,
        "eval_metric": "logloss"  # or "mlogloss" for multiclass
    }

    ##Build the pipeline
    pipeline_optuna=Pipeline(steps=[
        ("Preprocessing",Transfomers),
        ("Resampling SMOTE",SMOTE(random_state=42)),
        ("Random Forest Classifier",XGBClassifier(**params,random_state=42))
    ])

    ##cross validation score
    score=cross_val_score(pipeline_optuna,X_train,Y_train,cv=5,scoring="f1_weighted")
    return score.mean()

# %% [markdown]
# #### **Run the Optimizer**

# %%
study=optuna.create_study(
    study_name="xgb_model"
    ,direction="maximize")
study.optimize(objective,n_trials=50)
# Out:
# [I 2025-07-23 14:51:34,353] A new study created in memory with name: xgb_model
# [I 2025-07-23 14:51:39,416] Trial 0 finished with value: 0.6922805816871717 and parameters: {'n_estimators': 373, 'max_depth': 11, 'learning_rate': 0.027443441482314118, 'subsample': 0.5941592035033995, 'colsample_bytree': 0.68548055132781, 'gamma': 3.8601465847808285, 'reg_alpha': 0.01940586100957127, 'reg_lambda': 7.695070781553923e-05, 'min_child_weight': 14, 'scale_pos_weight': 5.869449015953036}. Best is trial 0 with value: 0.6922805816871717.
# [I 2025-07-23 14:51:40,205] Trial 1 finished with value: 0.713926845303725 and parameters: {'n_estimators': 253, 'max_depth': 9, 'learning_rate': 0.03857869564307303, 'subsample': 0.6955454124064395, 'colsample_bytree': 0.9819256790506072, 'gamma': 2.970260899576088, 'reg_alpha': 3.680244923481168e-08, 'reg_lambda': 0.00035013940335344344, 'min_child_weight': 4, 'scale_pos_weight': 8.855731614752315}. Best is trial 1 with value: 0.713926845303725.
# [I 2025-07-23 14:51:41,013] Trial 2 finished with value: 0.6798142453144385 and parameters: {'n_estimators': 342, 'max_depth': 14, 'learning_rate': 0.10009903159500479, 'subsample': 0.6363090968341522, 'colsample_bytree': 0.7286268118660533, 'gamma': 3.5224567183999875, 'reg_alpha': 1.4168818755965868, 'reg_lambda': 0.007710193721534236, 'min_child_weight': 12, 'scale_pos_weight': 9.886608142278881}. Best is trial 1 with value: 0.713926845303725.
# [I 2025-07-23 14:51:41,942] Trial 3 finished with value: 0.7140631966936921 and parameters: {'n_estimators': 422, 'max_depth': 4, 'learning_rate': 0.07455806146466283, 'subsample': 0.860901313128085, 'colsample_bytree': 0.5015340775899977, 'gamma': 3.724029833527156, 'reg_alpha': 0.009345183083149746, 'reg_lambda': 1.556389088760677e-06, 'min_child_weight': 4, 'scale_pos_weight': 4.57283069008523}. Best is trial 3 with value: 0.7140631966936921.
# [I 2025-07-23 14:51:42,844] Trial 4 finished with value: 0.7100305607972667 and parameters: {'n_estimators': 336, 'max_depth': 13, 'learning_rate': 0.02953401776770066, 'subsample': 0.5026064341823162, 'colsample_bytree': 0.8714388192037683, 'gamma': 2.49230765416949, 'reg_alpha': 0.09570984741504082, 'reg_lambda': 0.0029679415962662035, 'min_child_weight': 18, 'scale_pos_weight': 2.8520480247656437}. Best is trial 3 with value: 0.7140631966936921.
# [I 2025-07-23 14:51:43,565] Trial 5 finished with value: 0.6790819911427217 and parameters: {'n_estimators': 279, 'max_depth': 14, 'learning_rate': 0.04154504654783381, 'subsample': 0.5499196120313579, 'colsample_bytree': 0.8722809811428627, 'gamma': 4.964802302653051, 'reg_alpha': 7.460006342502074e-07, 'reg_lambda': 2.2635190010243944, 'min_child_weight': 12, 'scale_pos_weight': 4.067903824740056}. Best is trial 3 with value: 0.7140631966936921.
# [I 2025-07-23 14:51:44,588] Trial 6 finished with value: 0.7116250366304734 and parameters: {'n_estimators': 351, 'max_depth': 15, 'learning_rate': 0.0198160579619272, 'subsample': 0.6731420854902208, 'colsample_bytree': 0.7107482000853704, 'gamma': 0.742794138764048, 'reg_alpha': 1.1394850731091914, 'reg_lambda': 2.1825254809121007e-06, 'min_child_weight': 5, 'scale_pos_weight': 9.668210181050737}. Best is trial 3 with value: 0.7140631966936921.
# [I 2025-07-23 14:51:45,330] Trial 7 finished with value: 0.7150948310434344 and parameters: {'n_estimators': 309, 'max_depth': 4, 'learning_rate': 0.12072601249155927, 'subsample': 0.6600634599995194, 'colsample_bytree': 0.5500154829799482, 'gamma': 0.8171283506415389, 'reg_alpha': 4.836514489777527, 'reg_lambda': 2.577926416850431e-08, 'min_child_weight': 3, 'scale_pos_weight': 2.702932734867117}. Best is trial 7 with value: 0.7150948310434344.
# [I 2025-07-23 14:51:46,186] Trial 8 finished with value: 0.6994472629144466 and parameters: {'n_estimators': 393, 'max_depth': 9, 'learning_rate': 0.12224972257693313, 'subsample': 0.6954103812261998, 'colsample_bytree': 0.8280161642255659, 'gamma': 4.792220986095269, 'reg_alpha': 8.86403659087266e-05, 'reg_lambda': 1.0207163756987363, 'min_child_weight': 12, 'scale_pos_weight': 2.6461822919218085}. Best is trial 7 with value: 0.7150948310434344.
# [I 2025-07-23 14:51:47,168] Trial 9 finished with value: 0.6958023485439643 and parameters: {'n_estimators': 415, 'max_depth': 9, 'learning_rate': 0.013585742450176873, 'subsample': 0.9801458964696412, 'colsample_bytree': 0.8405085014412331, 'gamma': 4.030146980121342, 'reg_alpha': 1.3495491979215702e-07, 'reg_lambda': 8.288618309550262e-07, 'min_child_weight': 19, 'scale_pos_weight': 3.289090285787175}. Best is trial 7 with value: 0.7150948310434344.
# [I 2025-07-23 14:51:47,807] Trial 10 finished with value: 0.7230653803183522 and parameters: {'n_estimators': 139, 'max_depth': 3, 'learning_rate': 0.2656967339772206, 'subsample': 0.8145961828837013, 'colsample_bytree': 0.5026889796762313, 'gamma': 0.3110057381151634, 'reg_alpha': 5.1722480041605435e-05, 'reg_lambda': 1.5861828372864686e-08, 'min_child_weight': 8, 'scale_pos_weight': 1.307862632447692}. Best is trial 10 with value: 0.7230653803183522.
# [I 2025-07-23 14:51:48,706] Trial 11 finished with value: 0.7200042502150934 and parameters: {'n_estimators': 139, 'max_depth': 3, 'learning_rate': 0.224746545643927, 'subsample': 0.8113494162282348, 'colsample_bytree': 0.5169287964929847, 'gamma': 0.0405831675985171, 'reg_alpha': 3.083513114780455e-05, 'reg_lambda': 1.0877172437417074e-08, 'min_child_weight': 1, 'scale_pos_weight': 1.4903752817777642}. Best is trial 10 with value: 0.7230653803183522.
# [I 2025-07-23 14:51:49,516] Trial 12 finished with value: 0.719585590797912 and parameters: {'n_estimators': 118, 'max_depth': 6, 'learning_rate': 0.2957763061787457, 'subsample': 0.8081805270271223, 'colsample_bytree': 0.595894780802839, 'gamma': 0.05541500704790919, 'reg_alpha': 2.6786219345690117e-05, 'reg_lambda': 1.4258548888159901e-08, 'min_child_weight': 8, 'scale_pos_weight': 1.0254933775971804}. Best is trial 10 with value: 0.7230653803183522.
# [I 2025-07-23 14:51:50,043] Trial 13 finished with value: 0.7268542682101284 and parameters: {'n_estimators': 104, 'max_depth': 3, 'learning_rate': 0.2935759414969347, 'subsample': 0.8788461827113905, 'colsample_bytree': 0.6275238893160621, 'gamma': 1.6235664229942284, 'reg_alpha': 2.915055302429245e-06, 'reg_lambda': 1.4195895548729202e-07, 'min_child_weight': 1, 'scale_pos_weight': 1.0566675787035433}. Best is trial 13 with value: 0.7268542682101284.
# [I 2025-07-23 14:51:50,781] Trial 14 finished with value: 0.6993503486124577 and parameters: {'n_estimators': 193, 'max_depth': 6, 'learning_rate': 0.1969501250664225, 'subsample': 0.9798147368329303, 'colsample_bytree': 0.6156115577937887, 'gamma': 1.7425109535973284, 'reg_alpha': 1.7156649977565354e-06, 'reg_lambda': 2.5670570011131786e-07, 'min_child_weight': 8, 'scale_pos_weight': 6.622188547417933}. Best is trial 13 with value: 0.7268542682101284.
# [I 2025-07-23 14:51:52,307] Trial 15 finished with value: 0.7096557596132481 and parameters: {'n_estimators': 480, 'max_depth': 6, 'learning_rate': 0.1716895909719142, 'subsample': 0.8934236579573371, 'colsample_bytree': 0.6352601864008363, 'gamma': 1.653510993800555, 'reg_alpha': 0.0004321734200703386, 'reg_lambda': 2.0341755420754634e-05, 'min_child_weight': 8, 'scale_pos_weight': 1.788252670573179}. Best is trial 13 with value: 0.7268542682101284.
# [I 2025-07-23 14:51:53,134] Trial 16 finished with value: 0.712453606438346 and parameters: {'n_estimators': 181, 'max_depth': 3, 'learning_rate': 0.0660883887257228, 'subsample': 0.9080331576688132, 'colsample_bytree': 0.5707830804391856, 'gamma': 1.470190444470733, 'reg_alpha': 2.4699090336550295e-06, 'reg_lambda': 2.2505496721711316e-07, 'min_child_weight': 16, 'scale_pos_weight': 6.5713195622583225}. Best is trial 13 with value: 0.7268542682101284.
# [I 2025-07-23 14:51:53,874] Trial 17 finished with value: 0.7195559921707607 and parameters: {'n_estimators': 210, 'max_depth': 7, 'learning_rate': 0.2823348712464644, 'subsample': 0.7470459471617444, 'colsample_bytree': 0.6590021015976989, 'gamma': 1.0150217960490315, 'reg_alpha': 0.0012332374399426109, 'reg_lambda': 1.1275281501034728e-05, 'min_child_weight': 1, 'scale_pos_weight': 4.62799995122758}. Best is trial 13 with value: 0.7268542682101284.
# [I 2025-07-23 14:51:54,424] Trial 18 finished with value: 0.7159424029227353 and parameters: {'n_estimators': 105, 'max_depth': 5, 'learning_rate': 0.16632647411549586, 'subsample': 0.7801304872572442, 'colsample_bytree': 0.7800250478469909, 'gamma': 2.2774321690878536, 'reg_alpha': 1.3866042565801378e-08, 'reg_lambda': 1.0103599265423036e-07, 'min_child_weight': 7, 'scale_pos_weight': 1.8800610958139679}. Best is trial 13 with value: 0.7268542682101284.
# [I 2025-07-23 14:51:55,371] Trial 19 finished with value: 0.7191595926223873 and parameters: {'n_estimators': 163, 'max_depth': 8, 'learning_rate': 0.08958264643196256, 'subsample': 0.8604774506252322, 'colsample_bytree': 0.5508599535084662, 'gamma': 0.3943282161203875, 'reg_alpha': 6.898760781196077e-06, 'reg_lambda': 0.08232952848651963, 'min_child_weight': 10, 'scale_pos_weight': 7.5704391850042585}. Best is trial 13 with value: 0.7268542682101284.
# [I 2025-07-23 14:51:56,157] Trial 20 finished with value: 0.7121445725297895 and parameters: {'n_estimators': 233, 'max_depth': 11, 'learning_rate': 0.14798214853114308, 'subsample': 0.7517039632197532, 'colsample_bytree': 0.653096698735015, 'gamma': 1.3365660155331565, 'reg_alpha': 3.2336046195916834e-07, 'reg_lambda': 5.23811692990587e-06, 'min_child_weight': 6, 'scale_pos_weight': 3.699066115836351}. Best is trial 13 with value: 0.7268542682101284.
# [I 2025-07-23 14:51:56,872] Trial 21 finished with value: 0.7230579106767532 and parameters: {'n_estimators': 137, 'max_depth': 3, 'learning_rate': 0.23649524679703376, 'subsample': 0.8248410569024334, 'colsample_bytree': 0.5255010140921117, 'gamma': 0.01924006508144166, 'reg_alpha': 2.6214658442412535e-05, 'reg_lambda': 1.3684438369667123e-08, 'min_child_weight': 1, 'scale_pos_weight': 1.1377587486371743}. Best is trial 13 with value: 0.7268542682101284.
# [I 2025-07-23 14:51:57,570] Trial 22 finished with value: 0.7400051848798179 and parameters: {'n_estimators': 148, 'max_depth': 3, 'learning_rate': 0.24825467622706104, 'subsample': 0.9286183375726991, 'colsample_bytree': 0.5000721560167242, 'gamma': 0.4593647375325485, 'reg_alpha': 0.0015513340476672644, 'reg_lambda': 7.739996763666364e-08, 'min_child_weight': 1, 'scale_pos_weight': 1.9338765219454883}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:51:58,127] Trial 23 finished with value: 0.7206609870359996 and parameters: {'n_estimators': 103, 'max_depth': 4, 'learning_rate': 0.22418309668157627, 'subsample': 0.9296780155887415, 'colsample_bytree': 0.5862062760718127, 'gamma': 2.04718724026773, 'reg_alpha': 0.0012251086769263983, 'reg_lambda': 1.2470497301322288e-07, 'min_child_weight': 3, 'scale_pos_weight': 2.1940950987352754}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:51:58,792] Trial 24 finished with value: 0.7165856623583846 and parameters: {'n_estimators': 158, 'max_depth': 5, 'learning_rate': 0.2999720138099043, 'subsample': 0.9477894402238539, 'colsample_bytree': 0.5045825743352317, 'gamma': 0.5349033373651162, 'reg_alpha': 0.00016597506174586592, 'reg_lambda': 7.995064002733009e-08, 'min_child_weight': 2, 'scale_pos_weight': 2.0189166657095665}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:51:59,545] Trial 25 finished with value: 0.7155340417485425 and parameters: {'n_estimators': 219, 'max_depth': 5, 'learning_rate': 0.15965653924575623, 'subsample': 0.8687999184858445, 'colsample_bytree': 0.5591194987939669, 'gamma': 1.2455800584784302, 'reg_alpha': 0.0017628165305273327, 'reg_lambda': 4.902410551042682e-07, 'min_child_weight': 10, 'scale_pos_weight': 3.2607462916900447}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:00,232] Trial 26 finished with value: 0.7190510501928968 and parameters: {'n_estimators': 158, 'max_depth': 3, 'learning_rate': 0.13425302887880933, 'subsample': 0.9410047891769102, 'colsample_bytree': 0.601661006765316, 'gamma': 0.5176735178110796, 'reg_alpha': 0.006750543472861819, 'reg_lambda': 7.196383386822069e-05, 'min_child_weight': 5, 'scale_pos_weight': 1.0089121637406835}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:01,049] Trial 27 finished with value: 0.7204754520169165 and parameters: {'n_estimators': 265, 'max_depth': 4, 'learning_rate': 0.20555039330762187, 'subsample': 0.8403050736640596, 'colsample_bytree': 0.6723944986316481, 'gamma': 2.9072976301642743, 'reg_alpha': 6.1567077027486315e-06, 'reg_lambda': 5.194350672069078e-08, 'min_child_weight': 3, 'scale_pos_weight': 2.1635416074466973}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:01,655] Trial 28 finished with value: 0.7009919477895648 and parameters: {'n_estimators': 136, 'max_depth': 7, 'learning_rate': 0.10763805784366434, 'subsample': 0.8940690757702955, 'colsample_bytree': 0.7677650033140038, 'gamma': 1.9443991062160564, 'reg_alpha': 0.09325876447759257, 'reg_lambda': 3.2749303512972504e-06, 'min_child_weight': 14, 'scale_pos_weight': 5.274355137746099}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:02,415] Trial 29 finished with value: 0.7173432158851097 and parameters: {'n_estimators': 194, 'max_depth': 11, 'learning_rate': 0.04931538834847939, 'subsample': 0.7782752790198206, 'colsample_bytree': 0.6998339341722226, 'gamma': 1.048664106680343, 'reg_alpha': 0.04629414325847525, 'reg_lambda': 0.00011220208369107909, 'min_child_weight': 6, 'scale_pos_weight': 2.6278180842624024}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:03,131] Trial 30 finished with value: 0.7140787023559967 and parameters: {'n_estimators': 174, 'max_depth': 5, 'learning_rate': 0.08296628726212613, 'subsample': 0.9901637263972567, 'colsample_bytree': 0.5395364310269561, 'gamma': 0.44465550744462634, 'reg_alpha': 0.0003217420185468671, 'reg_lambda': 5.09338330667123e-07, 'min_child_weight': 15, 'scale_pos_weight': 1.5092433745018887}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:03,784] Trial 31 finished with value: 0.7239643103547173 and parameters: {'n_estimators': 134, 'max_depth': 3, 'learning_rate': 0.2320495606624109, 'subsample': 0.8248607755432169, 'colsample_bytree': 0.5251997740300242, 'gamma': 0.2462834100168944, 'reg_alpha': 3.823136731335974e-05, 'reg_lambda': 2.7782863963596987e-08, 'min_child_weight': 1, 'scale_pos_weight': 1.1159538271770142}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:04,430] Trial 32 finished with value: 0.7290402476465515 and parameters: {'n_estimators': 127, 'max_depth': 3, 'learning_rate': 0.25377177295662645, 'subsample': 0.7423386439177839, 'colsample_bytree': 0.6255516759676145, 'gamma': 0.30852289823862117, 'reg_alpha': 7.776186864281973e-05, 'reg_lambda': 3.143892403249399e-08, 'min_child_weight': 2, 'scale_pos_weight': 1.4670027001284285}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:05,016] Trial 33 finished with value: 0.7180334332189995 and parameters: {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.18802729430335147, 'subsample': 0.7296082956637593, 'colsample_bytree': 0.6263375161933411, 'gamma': 0.7732376365499816, 'reg_alpha': 8.979598558640584e-06, 'reg_lambda': 3.321966232959469e-08, 'min_child_weight': 2, 'scale_pos_weight': 2.3548714426646358}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:05,632] Trial 34 finished with value: 0.7151117839406341 and parameters: {'n_estimators': 132, 'max_depth': 3, 'learning_rate': 0.24079110944289253, 'subsample': 0.6161801924216217, 'colsample_bytree': 0.5768913914852619, 'gamma': 1.0611677166321218, 'reg_alpha': 9.78326683077552e-08, 'reg_lambda': 0.0007135247100719149, 'min_child_weight': 2, 'scale_pos_weight': 3.237225365152673}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:06,419] Trial 35 finished with value: 0.7106446270684581 and parameters: {'n_estimators': 242, 'max_depth': 4, 'learning_rate': 0.19086534720085657, 'subsample': 0.7841941419588229, 'colsample_bytree': 0.740487048306183, 'gamma': 2.7381271900026585, 'reg_alpha': 0.0052720607357216506, 'reg_lambda': 9.961281141909697e-08, 'min_child_weight': 4, 'scale_pos_weight': 1.5864756791763095}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:07,099] Trial 36 finished with value: 0.704215326603552 and parameters: {'n_estimators': 123, 'max_depth': 10, 'learning_rate': 0.14296878364691648, 'subsample': 0.7192258687411569, 'colsample_bytree': 0.9717772108585658, 'gamma': 3.332471169408329, 'reg_alpha': 0.00046891889728572817, 'reg_lambda': 1.257742981660358e-06, 'min_child_weight': 1, 'scale_pos_weight': 4.193332193631659}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:07,859] Trial 37 finished with value: 0.7239048000539499 and parameters: {'n_estimators': 158, 'max_depth': 5, 'learning_rate': 0.25013782386919386, 'subsample': 0.8589414194921983, 'colsample_bytree': 0.6914730672008788, 'gamma': 0.2275667505673357, 'reg_alpha': 1.4452380544869386e-06, 'reg_lambda': 4.165441553838749e-07, 'min_child_weight': 4, 'scale_pos_weight': 8.594911872007449}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:08,784] Trial 38 finished with value: 0.7202324316421949 and parameters: {'n_estimators': 201, 'max_depth': 7, 'learning_rate': 0.027458921135629658, 'subsample': 0.9161344868824055, 'colsample_bytree': 0.5314912081707388, 'gamma': 0.7074585408518015, 'reg_alpha': 0.00012595549809337757, 'reg_lambda': 4.710623647061292e-08, 'min_child_weight': 3, 'scale_pos_weight': 1.7274277246158947}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:09,807] Trial 39 finished with value: 0.7122728436326937 and parameters: {'n_estimators': 293, 'max_depth': 4, 'learning_rate': 0.021195382772070667, 'subsample': 0.9571990995426555, 'colsample_bytree': 0.637191255057059, 'gamma': 1.5305629932399496, 'reg_alpha': 1.2971392836650377e-05, 'reg_lambda': 1.401496020960565e-05, 'min_child_weight': 5, 'scale_pos_weight': 2.9158611645502104}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:10,791] Trial 40 finished with value: 0.7213258089794552 and parameters: {'n_estimators': 318, 'max_depth': 12, 'learning_rate': 0.06518280774090904, 'subsample': 0.8714319079974947, 'colsample_bytree': 0.726558278256873, 'gamma': 1.1614498713424255, 'reg_alpha': 0.020225672243213998, 'reg_lambda': 0.010853436553701485, 'min_child_weight': 2, 'scale_pos_weight': 3.6685536416864917}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:11,491] Trial 41 finished with value: 0.7174315937463389 and parameters: {'n_estimators': 154, 'max_depth': 3, 'learning_rate': 0.24697481356711853, 'subsample': 0.8444216931892806, 'colsample_bytree': 0.6999572601708363, 'gamma': 0.22899462728338899, 'reg_alpha': 8.476356844551915e-07, 'reg_lambda': 4.68990688425152e-07, 'min_child_weight': 4, 'scale_pos_weight': 8.242745975905477}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:12,065] Trial 42 finished with value: 0.7253489111987266 and parameters: {'n_estimators': 119, 'max_depth': 5, 'learning_rate': 0.26262605571662356, 'subsample': 0.8726997559894298, 'colsample_bytree': 0.6774418318895732, 'gamma': 0.7045632873545542, 'reg_alpha': 1.722560234551694e-06, 'reg_lambda': 2.022853553121895e-07, 'min_child_weight': 1, 'scale_pos_weight': 9.100758126437276}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:12,945] Trial 43 finished with value: 0.721907172269801 and parameters: {'n_estimators': 121, 'max_depth': 4, 'learning_rate': 0.010239089452931364, 'subsample': 0.8878638825553454, 'colsample_bytree': 0.6083358134342989, 'gamma': 0.8676236358929473, 'reg_alpha': 3.400441840024222e-06, 'reg_lambda': 3.547030984727653e-08, 'min_child_weight': 1, 'scale_pos_weight': 9.70718875872462}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:13,688] Trial 44 finished with value: 0.7114230783145975 and parameters: {'n_estimators': 179, 'max_depth': 3, 'learning_rate': 0.2993991147568166, 'subsample': 0.7888403195939595, 'colsample_bytree': 0.6671917495402218, 'gamma': 0.6325480367427958, 'reg_alpha': 6.138656082442641e-05, 'reg_lambda': 1.462088436284361e-06, 'min_child_weight': 2, 'scale_pos_weight': 6.314419672137983}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:14,352] Trial 45 finished with value: 0.7294556262764129 and parameters: {'n_estimators': 118, 'max_depth': 4, 'learning_rate': 0.2036960234030684, 'subsample': 0.6858487239834584, 'colsample_bytree': 0.5680049489778283, 'gamma': 0.3148417748649234, 'reg_alpha': 3.554400237798297e-07, 'reg_lambda': 1.6324985680555786e-07, 'min_child_weight': 3, 'scale_pos_weight': 5.402861840064383}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:14,969] Trial 46 finished with value: 0.7190184626219294 and parameters: {'n_estimators': 114, 'max_depth': 6, 'learning_rate': 0.11796070281310707, 'subsample': 0.6619526814541079, 'colsample_bytree': 0.5778053107994583, 'gamma': 0.9131956762328732, 'reg_alpha': 2.2073871721388493e-07, 'reg_lambda': 1.847431298536295e-07, 'min_child_weight': 3, 'scale_pos_weight': 7.594367926710866}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:15,717] Trial 47 finished with value: 0.7156619238454078 and parameters: {'n_estimators': 146, 'max_depth': 4, 'learning_rate': 0.03639154531552141, 'subsample': 0.6922557975088259, 'colsample_bytree': 0.6296886375631017, 'gamma': 0.603704179979483, 'reg_alpha': 4.404512290627827e-08, 'reg_lambda': 4.170586274740037e-06, 'min_child_weight': 4, 'scale_pos_weight': 5.449067794094516}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:16,957] Trial 48 finished with value: 0.7171304456845021 and parameters: {'n_estimators': 498, 'max_depth': 5, 'learning_rate': 0.1769859039646343, 'subsample': 0.6826108482575896, 'colsample_bytree': 0.555648500842657, 'gamma': 1.8236877477138178, 'reg_alpha': 4.5934262481203876e-07, 'reg_lambda': 1.0471801702508937e-06, 'min_child_weight': 5, 'scale_pos_weight': 9.21290449277974}. Best is trial 22 with value: 0.7400051848798179.
# [I 2025-07-23 14:52:17,514] Trial 49 finished with value: 0.706447039896269 and parameters: {'n_estimators': 119, 'max_depth': 8, 'learning_rate': 0.26332513195083695, 'subsample': 0.5775244808189945, 'colsample_bytree': 0.5964746517441357, 'gamma': 4.343721237384523, 'reg_alpha': 7.236705775442225e-08, 'reg_lambda': 5.473176018103176, 'min_child_weight': 2, 'scale_pos_weight': 4.904649911966309}. Best is trial 22 with value: 0.7400051848798179.

# %% [markdown]
# #### **Best Model**

# %%
best_model_optuna=study.best_params
print(f"Best Params:{best_model_optuna}")
# Out:
# Best Params:{'n_estimators': 148, 'max_depth': 3, 'learning_rate': 0.24825467622706104, 'subsample': 0.9286183375726991, 'colsample_bytree': 0.5000721560167242, 'gamma': 0.4593647375325485, 'reg_alpha': 0.0015513340476672644, 'reg_lambda': 7.739996763666364e-08, 'min_child_weight': 1, 'scale_pos_weight': 1.9338765219454883}

# %% [markdown]
# #### **Run the Pipeline with Best Parameters**

# %%
best_pipeline=Pipeline(steps=[
        ("Preprocessing",Transfomers),
        ("Resampling SMOTE",SMOTE(random_state=42)),
        ("Random Forest Classifier",XGBClassifier(random_state=42,**best_model_optuna))
    ])

# %% [markdown]
# #### **Train the Model with Best Parameters**

# %%
best_pipeline.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('Ordinal Pipeline',
#                                                   Pipeline(steps=[('Ordinal '
#                                                                    'Encoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['work_status',
#                                                    'social_activity_level',
#                                                    'exercise_frequency']),
#                                                  ('Nominal Pipeline',
#                                                   Pipeline(steps=[('Nominal '
#                                                                    'Encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'pem_presen...
#                                gamma=0.4593647375325485, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.24825467622706104, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=3,
#                                max_leaves=None, min_child_weight=1, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=148, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %% [markdown]
# #### **Evaluate the Model**

# %%
Y_pred_optuna=best_pipeline.predict(X_test) ##get the prediction values

# %%
report_xgb_optuna=classification_report(Y_test,Y_pred_optuna) ##get the classification report for predictions

# %%
Y_pred_train_optuna=best_pipeline.predict(X_train) ##get the preidction value for training set

# %%
report_xgb_train_optuna=classification_report(Y_train,Y_pred_train_optuna) ##get the classification report for training

# %% [markdown]
# #### **Get the Evaluation Metrics for Testing Data**

# %%
f1_test=f1_score(Y_test,Y_pred_optuna,average='weighted') ##F1 score for testing data
precision_test=precision_score(Y_test,Y_pred_optuna,average="weighted") ##precision for testing data
accuracy_test=accuracy_score(Y_test,Y_pred_optuna) ## accuracy score for testing data
recall_test=recall_score(Y_test,Y_pred_optuna,average="weighted") ## recall score for testing data

# %%
# Print results
print(f"Accuracy:  {accuracy_test:.4f}")
print(f"Precision: {precision_test:.4f}")
print(f"F1 Score:  {f1_test:.4f}")
print(f"Recall Score:{recall_test:.4f}")
# Out:
# Accuracy:  0.7833
# Precision: 0.7548
# F1 Score:  0.7634
# Recall Score:0.7833

# %% [markdown]
# #### **Get the Evaluation Metrics for Training Data**

# %%
f1_train=f1_score(Y_train,Y_pred_train_optuna,average="weighted") ##F1 score for training data
precision_train=precision_score(Y_train,Y_pred_train_optuna,average="weighted") ## precision score for training data
accuracy_train=accuracy_score(Y_train,Y_pred_train_optuna) ## accuracy score for training data
recall_train=recall_score(Y_train,Y_pred_train_optuna,average="weighted") ##recall score for training data

# %%
# Print results
print(f"Accuracy:  {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"F1 Score:  {f1_train:.4f}")
print(f"Recall Score:{recall_train:.4f}")
# Out:
# Accuracy:  0.7957
# Precision: 0.7814
# F1 Score:  0.7801
# Recall Score:0.7957

# %% [markdown]
# ## **Model Deployment using Mlflow**

# %%
import mlflow

# %%
import mlflow.sklearn
import mlflow.sklearn


mlflow.set_tracking_uri("http://127.0.0.1:5000/")
mlflow.set_experiment("XGB-Classifier")
#####Random Forest with Grid Search CV
with mlflow.start_run(run_name="XGB Classifier with Grid SearchCV"):
    mlflow.log_params(best_parameters)
    metrics_1={
        "accuracy":accuracy_score(Y_test,Y_pred_cv),
        "f1-score":f1_score(Y_test,Y_pred_cv,average='weighted'),
        "precision":precision_score(Y_test,Y_pred_cv,average="weighted"),
        "recall":recall_score(Y_test,Y_pred_cv,average="weighted")
    }

    for key,value in metrics_1.items():
        mlflow.log_metric(key,value)
    mlflow.sklearn.log_model(best_model,"XGB Classifier with Grid SearchCV")

##########################################################################################
### Random Forest with Optuna

with mlflow.start_run(run_name="XGB Classifier with Optuna"):
    mlflow.log_params(best_model_optuna)
    metrics_2={
        "accuracy":accuracy_score(Y_test,Y_pred_optuna),
        "f1-score":f1_score(Y_test,Y_pred_optuna,average='weighted'),
        "precision":precision_score(Y_test,Y_pred_optuna,average="weighted"),
        "recall":recall_score(Y_test,Y_pred_optuna,average="weighted")
    }
    for key,value in metrics_2.items():
        mlflow.log_metric(key,value)
    mlflow.sklearn.log_model(best_pipeline,"XGB Classifier with Optuna")
######################################################################################
# Out:
# 2025/07/24 00:37:31 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/24 00:37:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run XGB Classifier with Grid SearchCV at: http://127.0.0.1:5000/#/experiments/803709945066767617/runs/d779b8302e1f47eb9ff3ba650ab9d3aa
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/803709945066767617
# 2025/07/24 00:37:36 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/24 00:37:41 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run XGB Classifier with Optuna at: http://127.0.0.1:5000/#/experiments/803709945066767617/runs/638124db5a5e404e9bae83019bff4eed
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/803709945066767617
